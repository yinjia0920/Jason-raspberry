# %%
print("hello python")
# Out:
# hello python

# %%
a=5
b=2
print(a*b)
# Out:
# 10

# %%
from operator import truediv
from sys import float_repr_style


m1=20
m2=20.0
m3=True
m4="張英傑"
print (type(m1))
print (type(m4))
# Out:
# <class 'int'>
# <class 'str'>

# %%
apple=10
orange=20
print(f"apple有{apple}個,orange有{orange}個")
# Out:
# apple有10個,orange有20個
